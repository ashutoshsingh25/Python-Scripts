# %% [markdown]
# # This Script is responsible for following tasks
#
# -   Data Reading from the Excel file
# -   Data Files Separation

# %% [markdown]
# #### Importing all the Important and relevant Libraries and Modules

# %%
import pandas as pd
import xlrd
import csv
import fasttext
import re
import string
import numpy as np
from nltk.corpus import stopwords
from collections import defaultdict
from os import listdir
from os.path import isfile, join
import os
import random
import nltk
import csv

nltk.download('stopwords')
stop_words = stopwords.words('english')
os.getcwd()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\imart\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 'C:\\Users\\imart\\Downloads\\Excavator_Fasttext_test'

# %%
os.mkdir("./Excavator_Fasttext_test")

# %%
os.chdir("./Excavator_Fasttext_test")

# %%
input_file_name = "C:\\Users\\imart\\Downloads\\Excavator_Fasttext_test\\excavator_subcat_155_new.xlsx"
subcat_name = "155"
base_directory="C:\\Users\\imart\\Downloads\\Excavator_Fasttext_test"
child_directory = str(base_directory)+"subcat_155/child/output_155/"
search_file_name = "C:\\Users\\imart\\Downloads\\Excavator_Fasttext_test\\subcat_155_title_search - Sheet2.tsv"

# %%
if not os.path.exists(str(base_directory)+"subcat_"+subcat_name):
    os.mkdir(str(base_directory)+"subcat_"+subcat_name)
    print("Directory " , str(base_directory)+"subcat_"+subcat_name ,  " Created ")
else:    
    print("Directory " , str(base_directory)+"subcat_"+subcat_name ,  " already exists")
# Out:
# Directory  C:\Users\imart\Downloads\subcat_155  already exists

# %%
#path where all xmls are kept
base_directory = base_directory+"subcat_"+subcat_name+"/"

os.mkdir(str(base_directory)+"pmcat/")
os.mkdir(base_directory+"child/")

def create_folders(name):
    input_path= base_directory+name+"/"+"input_"+subcat_name+"/"
    os.mkdir(input_path)
    output_path= base_directory+name+"/"+"output_"+subcat_name+"/"
    os.mkdir(output_path)
    KFold_Validation_Files_path= base_directory+name+"/"+"kFold_validation_"+subcat_name+"/"
    os.mkdir(KFold_Validation_Files_path)
    model_path=base_directory+name+"/"+"model_"+subcat_name+"/"
    os.mkdir(model_path)
    return True

create_folders("pmcat")
create_folders("child")

combined_parsed_file_name="combined.txt"
combined_shuffled_file_name="combined_shuffled.txt"
train_file_name="singleLabel_train_"+subcat_name
test_file_name="single_label_test_"+subcat_name
model_name="supervised_classifier_model_CATID_"+subcat_name
split=.9
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-27-c101b0f14a7c> in <module>()
#       2 base_directory = base_directory+"subcat_"+subcat_name+"/"
#       3
# ----> 4 os.mkdir(str(base_directory)+"pmcat/")
#       5 os.mkdir(base_directory+"child/")
#       6
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\imart\\Downloads\\subcat_155/pmcat/'

# %%
url = "http://fts-master.intermesh.net:8020/solr/mcat/select?q.alt=*:*&fl=id,name,catid,catname,parentmcat&wt=csv&csv.separator=%09&rows=200000"
mcat_data = pd.read_csv("mcat_data.csv" ,sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-4b2216f103f8> in <module>()
#       1 url = "http://fts-master.intermesh.net:8020/solr/mcat/select?q.alt=*:*&fl=id,name,catid,catname,parentmcat&wt=csv&csv.separator=%09&rows=200000"
# ----> 2 mcat_data = pd.read_csv("mcat_data.csv" ,sep='\t')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'mcat_data.csv' does not exist

# %%
# with open('../complete_product_data/mcat_data/mcat_data.csv', mode='r') as infile:
#     reader = csv.reader(infile, delimiter='\t')
#     mcat_data_id_name = {rows[0]:rows[1] for rows in reader}

# %%
from collections import OrderedDict

def remove_stopwords_and_duplicate_words(df, fieldName):
    df[fieldName] = df[fieldName].apply(lambda x: ' '.join([item for item in str(x).split() if item not in stop_words]))
    df[fieldName] = df[fieldName].str.split().apply(lambda x: OrderedDict.fromkeys(str(x).split()).keys()).str.join(' ')
    df[fieldName] = df[fieldName].replace('[^\w\s]','', regex=True).replace(' +',' ', regex=True)
    return df

def remove_punctuation(df, fieldName):
    excludePunctuation = set(string.punctuation)
    df[fieldName] = df[fieldName].apply(lambda x: ' '.join([item for item in str(x).split() if item not in excludePunctuation]))
    return df

def get_bulleted_data(df):
    regex = re.compile("<ul>(.*?)</ul>")
    df['REFINED_SMALL_DESC_BULLET'] = df.SMALL_DESC.apply(lambda x: [' '.join(re.findall(regex,str(x))) if len(re.findall(regex,str(x))) > 0 else '']).str.join(' ')
#     df['REFINED_SMALL_DESC'] = df.SMALL_DESC.apply(lambda x: print(x))

    return df

def get_bold_data(df):
    regex = re.compile("<b>(.*?)</b>")
    df['REFINED_SMALL_DESC_BOLD'] = df.SMALL_DESC.apply(lambda x: [' '.join(re.findall(regex,str(x))) if len(re.findall(regex,str(x))) > 0 else '']).str.join(' ')
#     df['REFINED_SMALL_DESC'] = df.SMALL_DESC.apply(lambda x: print(x))

    return df

def get_table_data(df):
    regex = re.compile("<td>(.*?)</td>")
    df['REFINED_SMALL_DESC_TABLE'] = df.SMALL_DESC.apply(lambda x: [' '.join(re.findall(regex,str(x))) if len(re.findall(regex,str(x))) > 0 else '']).str.join(' ')
#     df['REFINED_SMALL_DESC'] = df.SMALL_DESC.apply(lambda x: print(x))

    return df

def refine_dataframe_title(df):
    df['REFINED_TITLE'] = df['TITLE'].str.lower().replace(' +',' ', regex=True).replace('[^\w\s]','', regex=True).replace(' +',' ', regex=True)
    df = remove_stopwords_and_duplicate_words(df,'REFINED_TITLE')
    
#     display(df[['TITLE','REFINED_TITLE']])
    return df

def refine_dataframe_description(df):
#     df.SMALL_DESC.fillna(value=pd.np.nan, inplace=True)
    df = get_bulleted_data(df)
#     df = get_bold_data(df)
#     df = get_table_data(df)
#     df['REFINED_SMALL_DESC'] = df['REFINED_SMALL_DESC_BULLET']+ " " + df['REFINED_SMALL_DESC_BOLD']+ " " + df['REFINED_SMALL_DESC_TABLE']
    df['REFINED_SMALL_DESC'] = df['REFINED_SMALL_DESC_BULLET']
    df['REFINED_SMALL_DESC'] = df['REFINED_SMALL_DESC'].replace('<li>',' ',regex=True).replace('</li>',' ',regex=True).replace(' +', ' ',regex=True).replace('</li li>',' ',regex=True).replace('<ol>',' ',regex=True).replace('</ol/>',' ',regex=True).replace('</ul>',' ',regex=True).replace('<ul>',' ',regex=True).replace('<p>',' ',regex=True).replace('</p>',' ',regex=True).replace('<sup>',' ',regex=True).replace('</sup>',' ',regex=True).replace('<b>',' ',regex=True).replace('</b>',' ',regex=True).replace('<br/>',' ',regex=True).replace('<br>',' ',regex=True).replace('<br />',' ',regex=True).replace('[[:punct:]]',' ',regex=True).replace('[0-9] \\w+ *', '',regex=True).replace('[0-9]\\w+ *', '',regex=True).replace('[0-9]', '',regex=True).replace('\\s+',' ',regex=True).replace(' +', ' ',regex=True).replace(np.nan, '', regex=True)
    df = remove_punctuation(df, 'REFINED_SMALL_DESC')
    df['REFINED_SMALL_DESC'] = df['REFINED_SMALL_DESC'].str.lower()
    df = remove_stopwords_and_duplicate_words(df,'REFINED_SMALL_DESC')
    
#     display(df[['SMALL_DESC','REFINED_SMALL_DESC']])
    return df

def refine_dataframe_isq(df):
    df['REFINED_ISQ'] = df['ISQ_DETAILS4_INDEX'].str.lower().replace(' +',' ', regex=True).str.replace('[^\w\s]','', regex=True).str.replace('[0-9] \\w+ *','', regex=True).str.replace('[0-9]\\w+ *', '', regex=True).str.replace('[0-9]', '', regex=True).str.replace(' +',' ', regex=True).replace(np.nan, '', regex=True)
    df = remove_punctuation(df, 'REFINED_ISQ')
    df = remove_stopwords_and_duplicate_words(df,'REFINED_ISQ')

#     display(df[['ISQ_DETAILS4_INDEX','REFINED_ISQ']])
    return df

def refine_dataframe_combinedCorpus(df):
    df['REFINED_COMBINED_DATA'] = df['COMBINED_DATA'].replace(' +',' ', regex=True).replace('NA','', regex=True).str.lower().str.replace('[^\w\s]','', regex=True).str.replace(' +',' ', regex=True)
    df = remove_punctuation(df, 'REFINED_COMBINED_DATA')
    df = remove_stopwords_and_duplicate_words(df,'REFINED_COMBINED_DATA')

#     display(df[['COMBINED_DATA','REFINED_COMBINED_DATA']])
    return df

def clean_and_preProcess_data(df_data):
    df_refined = refine_dataframe_title(df_data)
    df_refined = refine_dataframe_description(df_refined)
    df_refined = refine_dataframe_isq(df_refined)
    
    df_refined['COMBINED_DATA'] = df_refined['REFINED_TITLE']+ " " + df_refined['REFINED_SMALL_DESC']+ " " + df_refined['REFINED_ISQ']
    
    df_refined = refine_dataframe_combinedCorpus(df_refined)
    df_refined['PRIME_MCAT_NAME'] = df_refined['PRIME_MCAT_NAME'].replace(' ','_', regex=True)
    df_refined['SEARCH_TOPMOST_MCAT'] = df_refined['SEARCH_TOPMOST_MCAT'].str.lower()
    df_refined['FASTTEXT_CORPUS'] = "__label__" + df_refined['PRIME_MCAT_NAME']+ " " + df_refined['REFINED_COMBINED_DATA'] + " " + df_refined['SEARCH_TOPMOST_MCAT']

#     display(df_refined[['FASTTEXT_CORPUS','PRIME_MCAT_NAME','REFINED_COMBINED_DATA']])
    df_refined['FASTTEXT_CORPUS'].replace("", np.nan, inplace=True)
    df_refined.FASTTEXT_CORPUS.dropna()
    return df_refined

# %%
stop_words.extend(("we","are","dealing","quality","manufacturers","manufacturer","exporters","supplier","dealer",
                 "good","topmost","business","trusted","finest","offer","offering","involved","provide","reputed",
                   "company","organization","trader","trading","inr","indian","rupees",
                    "rupee","features","specifications","material","feature","specification","materials",
                   "size","li","pvt.","ltd","pvt","ltd."))

# title,mcatid,mcatname,catid,catname,smalldesc,isq

def get_file_names_to_parse(input_path):
    files_to_parse = [join(input_path,f) for f in listdir(input_path) if isfile(join(input_path, f))]
    print("Total Files to Parse="+str(len(files_to_parse)))
    return files_to_parse

def generateLabel(mcatNames,combinedTitleDescIsq,prime_mcat_name):
    label_prefix="__label__"
    parsed_strings=[]
    labels=""
    fastTextLabel=""
#     print(prime_mcat_name)
    if prime_mcat_name != "" and combinedTitleDescIsq != "" and combinedTitleDescIsq not in ['\n', '\r\n']:
        labels = label_prefix+prime_mcat_name.replace(" ","_")
#         for eachMcat in mcatNames:
#             if labels == "":
#                 labels=labels+label_prefix+eachMcat.replace(" ","_")
#             else:
#                 labels=labels+" "+label_prefix+eachMcat.replace(" ","_")
    
        if labels!="":
            mcatName_str = ' '.join(mcatNames)            
            fastTextLabel= labels+" "+combinedTitleDescIsq+" "+mcatName_str
    return fastTextLabel

def refined_combined_title_desc_isq(combinedWord):
    combinedWord = re.sub(' +', ' ',combinedWord)
    combinedWord = re.sub(r'NA','',combinedWord)
    combinedWord = combinedWord.lower()
    combinedWord = (' '.join(remove_duplicates(combinedWord.split()))).lstrip()
    combinedWord = re.sub(r'[0-9] \\w+ *','',combinedWord)
    combinedWord = re.sub(r'[0-9]\\w+ *','',combinedWord)
    combinedWord = re.sub(r'[0-9]','',combinedWord)
    exclude = set(string.punctuation)
    combinedWord = ''.join(ch for ch in combinedWord if ch not in exclude)
    combinedWord = re.sub(r':','',combinedWord)
    combinedWord = removeStopWords(combinedWord)
    combinedWord = re.sub(' +', ' ',combinedWord)
    
    return combinedWord

def preProcess(file):
    parsed_strings=[]
    df_data = pd.read_csv(file, sep='\t', engine='python')
    df_refined = refine_dataframe_title(df_data)
    df_refined = refine_dataframe_description(df_refined)
    df_refined = refine_dataframe_isq(df_refined)
    
    df_refined['COMBINED_DATA'] = df_refined['REFINED_TITLE']+ " " + df_refined['REFINED_SMALL_DESC']+ " " + df_refined['REFINED_ISQ']
    
    df_refined = refine_dataframe_combinedCorpus(df_refined)
    
    df_refined['FASTTEXT_CORPUS'] = "__label__" + df_refined['PRIME_MCAT_NAME']+ " " + df_refined['REFINED_COMBINED_DATA']

#     display(df_refined[['FASTTEXT_CORPUS','PRIME_MCAT_NAME','REFINED_COMBINED_DATA']])
    
    df_refined.FASTTEXT_CORPUS.dropna()
    
    parsed_strings = df_refined['FASTTEXT_CORPUS'].tolist()
    
#     with open(file, mode='r') as csvfile:
#         readCSV = csv.reader(csvfile, delimiter='\t')
#         for column in readCSV:
#             combinedTitleDescIsq = ""
#             mcatNames = []
#             prime_mcat_name = ""
#             refinedTitle = ""
#             refinedIsq = ""
#             refinedDescription = ""
    
#             if len(column) == 7 and column[0] != "":
#                 title = column[0]
#                 refinedTitle = refineTitle(title)
# #                 print(refinedTitle)
#                 if column[1] != "":
#                     smallDesc = column[1]
#                     regex = re.compile("<ul>(.*?)</ul>")
# #                     regex = "<ul>" + '(.*?)' + "</ul>"
#                     impDesc = re.findall(regex,smallDesc)
#                     if len(impDesc) > 0:
#                         smallDesc = " ".join(impDesc)
#                         refinedDescription = refine_description(smallDesc)
# #                         print(refinedDescription)
#                     else:
#                         refinedDescription = ""
# #                     print(refinedDescription)
#                 if column[5] != "":
#                     isq = column[5]
# #                     allisqs = re.split(r'\t', isq)
#                     refinedIsq = refineIsq(isq)

#                 if column[2] != "":
#                     prime_mcat_name = column[2]
#             else:
#                 next
            
#             if refinedTitle != "" and refinedTitle != "title":
#                 combinedTitleDescIsq = combinedTitleDescIsq + refinedTitle
#                 if refinedDescription != "" and refinedDescription != "smalldesc":
#                     combinedTitleDescIsq = combinedTitleDescIsq + " " + refinedDescription
#                 if refinedIsq != "" and refinedIsq != "isq":
#                     combinedTitleDescIsq = combinedTitleDescIsq + " " + refinedIsq
                
#                 combinedTitleDescIsq = refined_combined_title_desc_isq(combinedTitleDescIsq)
#                 fastTextLabel = generateLabel(mcatNames,combinedTitleDescIsq,prime_mcat_name)
#                 parsed_strings.append(fastTextLabel)
#             else:
#                 next
    return parsed_strings

def remove_duplicates(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

def refineTitle(title):
    title = re.sub(' +', ' ',title)
    title = title.lower()
    title = re.sub(r'[[:punct:]]','',title)
    exclude = set(string.punctuation)
    title = ''.join(ch for ch in title if ch not in exclude)
    title = re.sub(r'[0-9] \\w+ *', '',title)
    title = re.sub(r'[0-9]\\w+ *', '',title)
    title = re.sub(r'[[:digit:]]','',title)
    title = re.sub(' +', ' ',title)
    
    return title
    
def refineIsq(allisqs):
    concatinatedIsq = re.sub(' +', ' ',allisqs)
    concatinatedIsq = concatinatedIsq.lower()
    concatinatedIsq = (' '.join(remove_duplicates(concatinatedIsq.split()))).lstrip()
    concatinatedIsq = re.sub(r'[^\w\s]','',concatinatedIsq)
    concatinatedIsq = re.sub(r'[[:punct:]]',' ',concatinatedIsq)
    exclude = set(string.punctuation)
    concatinatedIsq = ''.join(ch for ch in concatinatedIsq if ch not in exclude)
    concatinatedIsq = re.sub(r'[0-9] \\w+ *','', concatinatedIsq)
    concatinatedIsq = re.sub(r'[0-9]\\w+ *','', concatinatedIsq)
    concatinatedIsq = re.sub(r'[0-9]','', concatinatedIsq)
    concatinatedIsq = re.sub(' +', ' ',concatinatedIsq)
    concatinatedIsq = concatinatedIsq.lstrip()
    concatinatedIsq = concatinatedIsq.rstrip()
    concatinatedIsq = removeStopWords(concatinatedIsq)
    concatinatedIsq = re.sub(' +', ' ',concatinatedIsq)
    
    return concatinatedIsq

def refine_description(smallDesc):
    
    smallDesc = smallDesc.lower()
    smallDesc = re.sub(r',',' ',smallDesc)
    smallDesc = re.sub(' +', ' ',smallDesc)
    smallDesc = re.sub(r'</li li>',' ',smallDesc)
    smallDesc = re.sub(r'</li>',' ',smallDesc)
    smallDesc = re.sub(r'<li>',' ',smallDesc)
    smallDesc = re.sub(r'<ol>',' ',smallDesc)
    smallDesc = re.sub(r'</ul>',' ',smallDesc)
    smallDesc = re.sub(r'<ul>',' ',smallDesc)
    smallDesc = re.sub(r'<p>',' ',smallDesc)
    smallDesc = re.sub(r'</p>',' ',smallDesc)
    smallDesc = re.sub(r'<sup>',' ',smallDesc)
    smallDesc = re.sub(r'</sup>',' ',smallDesc)
    smallDesc = re.sub(r'<b>',' ',smallDesc)
    smallDesc = re.sub(r'<br />',' ',smallDesc)
    smallDesc = re.sub(r'[[:punct:]]',' ',smallDesc)
    exclude = set(string.punctuation)
    smallDesc = ''.join(ch for ch in smallDesc if ch not in exclude)
    smallDesc = re.sub(r'[0-9] \\w+ *', '',smallDesc)
    smallDesc = re.sub(r'[0-9]\\w+ *', '',smallDesc)
    smallDesc = re.sub(r'[0-9]', '',smallDesc)
    smallDesc = re.sub(r'\\s+',' ',smallDesc.strip())
    smallDesc = (' '.join(remove_duplicates(smallDesc.split()))).lstrip()
    smallDesc = re.sub(' +', ' ',smallDesc)
    smallDesc = removeStopWords(smallDesc)
    smallDesc = re.sub(' +', ' ',smallDesc)
    
    return smallDesc

def removeStopWords(word):
    tokenized_word = word.split()
    list_of_word = []
    [list_of_word.append(word) for word in tokenized_word if word not in stop_words]
    finalWord = " ".join(list_of_word)
    
    return finalWord

def write_to_file(parsed_strings,output_path,output_file_name,new_line_flag):
    train_data = open(output_path+output_file_name, 'w')
    for item in parsed_strings:
        if new_line_flag == True:
            train_data.write(str(item)+"\n")
        else:
            train_data.write(str(item))
    train_data.close()
    
def randomly_shuffle_file(input_file,output_file):
    data_array=[]
    with open(input_file,'r') as source:
        data = [(random.random(), line) for line in source ]
    data.sort()
    with open(output_file,'w') as target:
        for _, line in data:
            target.write( line )
            data_array.append(line)
    return data_array
            
def merge_files_in_folder(folder_path,output_filename):
    filenames = get_file_names_to_parse(folder_path)
    with open(folder_path+output_filename, 'w') as outfile:
        for fname in filenames:
            with open(fname) as infile:
                for line in infile:
                    outfile.write(line)

# %%
def readCsvOrExcel(file):
#     df = pd.read_csv(file,sep='\t')
    df = pd.read_excel(file,sheet_name=None)
    return df

def getPmcatData(complete_dataFrame):
    # Get Good and Super PMCAT Data
    df_pmcat_data = df[(df.FK_MCAT_TYPE_ID == 1) | (df.FK_MCAT_TYPE_ID == 2)]
    df_pmcat_data_fields = df_pmcat_data[['TITLE','SMALL_DESC','PRIME_MCAT_NAME','FK_MCAT_TYPE_ID','PRIME_SUBCAT_ID','ISQ_DETAILS4_INDEX','MAP_MCAT_NAMELIST','SEARCH_TOPMOST_MCAT']].copy()
    
    # Get Thin PMCAT data with their NAME if its PMCAT is not Good PMCAT
    df_pmcat_thin = df[(df.FK_MCAT_TYPE_ID == 3) & (df.PMCAT_MCAT_TYPE != 2)]
    df_pmcat_thin_fields = df_pmcat_thin[['TITLE','SMALL_DESC','PRIME_MCAT_NAME','FK_MCAT_TYPE_ID','PRIME_SUBCAT_ID','ISQ_DETAILS4_INDEX','MAP_MCAT_NAMELIST','SEARCH_TOPMOST_MCAT']].copy()
    
    df_pmcat_thinAndChild = df[(df.PMCAT_MCAT_TYPE == 2)]
    df_pmcat_thinAndChild_fields = df_pmcat_thinAndChild[['TITLE','SMALL_DESC','PMCAT_NAME','PMCAT_MCAT_TYPE','PRIME_SUBCAT_ID','ISQ_DETAILS4_INDEX','MAP_MCAT_NAMELIST','SEARCH_TOPMOST_MCAT']].copy()
    df_pmcat_thinAndChild_fields.rename(columns={'PMCAT_NAME': 'PRIME_MCAT_NAME','PMCAT_MCAT_TYPE': 'FK_MCAT_TYPE_ID'}, inplace=True)
    
    # Loose Mcats directly mapped in subcats
    df_looseMcats = df[df.PMCAT_NAME.isna()]
    df_looseMcats_fields = df_looseMcats[['TITLE','SMALL_DESC','PMCAT_NAME','PMCAT_MCAT_TYPE','PRIME_SUBCAT_ID','ISQ_DETAILS4_INDEX','MAP_MCAT_NAMELIST','SEARCH_TOPMOST_MCAT']].copy()
    df_looseMcats_fields.rename(columns={'PMCAT_NAME': 'PRIME_MCAT_NAME','PMCAT_MCAT_TYPE': 'FK_MCAT_TYPE_ID'}, inplace=True)
    
    combined_df_pmcat = pd.concat([df_pmcat_data_fields, df_pmcat_thinAndChild_fields, df_looseMcats_fields, df_pmcat_thin_fields])
    
    return combined_df_pmcat

def refine_pmcat_data(pmcat_training_data):
    for index, row in pmcat_training_data.iterrows():
        if len(mcat_data.loc[(mcat_data['name'] == row.PRIME_MCAT_NAME) & (mcat_data['catid'] == int(subcat_name))]) > 0:
            next
        else:
            pmcat_training_data.drop(index, inplace=True)
    return pmcat_training_data

def get_child_data(df):
    df_child_data_1 = df[(df.FK_MCAT_TYPE_ID != 1) & (df.FK_MCAT_TYPE_ID != 2)]
#     df_child_data_3 = df[df.FK_MCAT_TYPE_ID.isna()]
    df_child_data = pd.concat([df_child_data_1])
    return df_child_data

def get_childData_groups(df_child_data):
    df_child_groups = df_child_data.groupby(["PMCAT_NAME"])
    return df_child_groups

def refined_child_groups(df_child_data):
    count=1
    df_child_groups = get_childData_groups(df_child_data)
    for name,group in df_child_groups:
        count = count+1
#         if (len(mcat_data.loc[(mcat_data['name'] == name) & (mcat_data['catid'] == int(subcat_name))]) > 0) and (len(df_child_data.loc[(df_child_data['PMCAT_NAME'] == name) & ((df_child_data['PMCAT_MCAT_TYPE'] == 2))]) > 0):
        if (len(mcat_data.loc[(mcat_data['name'] == name) & (mcat_data['catid'] == int(subcat_name))]) > 0):
            if (len(df_child_data.loc[(df_child_data['PMCAT_NAME'] == name) & (df_child_data['PMCAT_MCAT_TYPE'] == 2)]) > 0):
                next
            elif (len(df_child_data.loc[(df_child_data['PMCAT_NAME'] == name) & (df_child_data['PMCAT_MCAT_TYPE'] == 3)]) > 0):
                next
            else:
                df_child_data = df_child_data.drop(df_child_groups.get_group(name).index)
        else:
            df_child_data = df_child_data.drop(df_child_groups.get_group(name).index)
       
    df_child_groups = get_childData_groups(df_child_data)

    return df_child_groups

def remove_newline_character(df):
    df = df.replace('\\n','', regex=True)
    df = df.replace('\n','', regex=True)
    return df

def write_dataframe_to_csv(base_directory, file_name, df):
    df.to_csv(base_directory + file_name, index=False, sep='\t', encoding='utf-8')

# %%
# df = preProcess("./FastText_POC/input_155/product_data_excavator_155_1.csv")
df_complete = readCsvOrExcel(input_file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-ea9e88377215> in <module>()
#       1 # df = preProcess("./FastText_POC/input_155/product_data_excavator_155_1.csv")
# ----> 2 df_complete = readCsvOrExcel(input_file_name)
#
# <ipython-input-17-fac2bb5996f2> in readCsvOrExcel(file)
#       2 def readCsvOrExcel(file):
#       3 #     df = pd.read_csv(file,sep='\t')
# ----> 4     df = pd.read_excel(file,sheet_name=None)
#       5     return df
#       6
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     305
#     306     if not isinstance(io, ExcelFile):
# --> 307         io = ExcelFile(io, engine=engine)
#     308
#     309     return io.parse(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     392             self.book = xlrd.open_workbook(file_contents=data)
#     393         elif isinstance(self._io, compat.string_types):
# --> 394             self.book = xlrd.open_workbook(self._io)
#     395         else:
#     396             raise ValueError('Must explicitly set engine if not passing in'
#
# ~\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     114         peek = file_contents[:peeksz]
#     115     else:
# --> 116         with open(filename, "rb") as f:
#     117             peek = f.read(peeksz)
#     118     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: './excavator_subcat_155_new.xlsx'

# %%
df = df_complete.get("subcat_"+subcat_name)

# %%
search_data = pd.read_csv(str(search_file_name), sep="\t")

# %%
df["SEARCH_TOPMOST_MCAT"] = search_data['SEARCH_TOPMOST_MCAT']

# %%
display(df)
# Out:
#        SELLERS_DISPLAY_ID  SELLERS_DATA_REFID  FK_GLUSR_USR_ID  \
# 0             18784542748           117610873         58521286
# 1             13968905191            92325917          2850251
# 2             13968905191            92325917          2850251
# 3             14698895697            96561192         29629451
# 4             14698895697            96561192         29629451
# 5              9919066230            69186153          3034425
# 6              9919066230            69186153          3034425
# 7             19812618297           127258326         65600416
# 8             19812618297           127258326         65600416
# 9             13282175797            88046650          4196482
# 10            13282175797            88046650          4196482
# 11            19521357012           124345714         20772382
# 12            19521357012           124345714         20772382
# 13            19521357012           124345714         20772382
# 14            19521357012           124345714         20772382
# 15            19392143030           123053573         18839062
# 16            18140463597           114387548         15412012
# 17            18140463597           114387548         15412012
# 18            16092866097           103989348         14630679
# 19            16092866097           103989348         14630679
# 20            16092866097           103989348         14630679
# 21            15984307230           103454654           516034
# 22            19950232073           128634464         69104252
# 23            19950232073           128634464         69104252
# 24            19950232073           128634464         69104252
# 25            19682467233           125956816         59514876
# 26            19300941430           122141557         18042704
# 27            19300941430           122141557         18042704
# 28            16354664397           105411011         16261014
# 29            17063967333           109037478         11787713
# ...                   ...                 ...              ...
# 89155         17039937712           108922679          1770580
# 89156         17039937712           108922679          1770580
# 89157         17039937712           108922679          1770580
# 89158          5276603848            38096917          2185183
# 89159         13406548412            88800158         23454470
# 89160         18991979297           119051935         58894435
# 89161          9764050191            68164594         14867975
# 89162         19981168897           128943832          1422959
# 89163         19981168897           128943832          1422959
# 89164         19981168897           128943832          1422959
# 89165         19260948630           121741629         13309618
# 89166         19260948630           121741629         13309618
# 89167         19260948630           121741629         13309618
# 89168          5416959762            39350373          8381363
# 89169          5416959762            39350373          8381363
# 89170          5570624012            40869435          1324389
# 89171         10470142933            70872898         22978558
# 89172         19675313412           125885278         67770363
# 89173         19675313412           125885278         67770363
# 89174          8082786762            58957823         12554889
# 89175          8082786762            58957823         12554889
# 89176         19921980888           128351952          4176963
# 89177         19921980888           128351952          4176963
# 89178         16267082812           104897850          2406088
# 89179         16267082812           104897850          2406088
# 89180          7501603148            55403454         11304160
# 89181         19447177648           123603920         56384564
# 89182          5538658891            40552336           891179
# 89183          8407265055            60750449          2345420
# 89184         17862289773           113051934         21855595
#
#                                                    TITLE  \
# 0        450/10800 JCB Casting Assy Differential Housing
# 1                          Mini Ride On Vibratory Roller
# 2                          Mini Ride On Vibratory Roller
# 3                                          Crawler Dozer
# 4                                          Crawler Dozer
# 5                              Off-Highway Mining Trucks
# 6                              Off-Highway Mining Trucks
# 7                                  L&T 9020 Wheel Loader
# 8                                  L&T 9020 Wheel Loader
# 9                                Used Komatsu D355 Dozer
# 10                               Used Komatsu D355 Dozer
# 11                                 Trench Digger Machine
# 12                                 Trench Digger Machine
# 13                                 Trench Digger Machine
# 14                                 Trench Digger Machine
# 15                                   Yellow JCB Wear Pad
# 16                                 L&T 9020 Wheel Loader
# 17                                 L&T 9020 Wheel Loader
# 18                               L933 3-Ton Wheel Loader
# 19                               L933 3-Ton Wheel Loader
# 20                               L933 3-Ton Wheel Loader
# 21                                      JCB Synchronizer
# 22                                Polished Excavator Pin
# 23                                Polished Excavator Pin
# 24                                Polished Excavator Pin
# 25                                        JCB Tooth Bolt
# 26                        Sany SY210C-9 21 Ton Excavator
# 27                        Sany SY210C-9 21 Ton Excavator
# 28                                        JCB Bucket Pin
# 29                                Tractor Backhoe Loader
# ...                                                  ...
# 89155                              JCB Skid Steer Loader
# 89156                              JCB Skid Steer Loader
# 89157                              JCB Skid Steer Loader
# 89158                                  Toro Power Shovel
# 89159                Plant Hire Earth Movers Contractors
# 89160                              Landt Poclain Machine
# 89161                                    Backhoes Loader
# 89162  Volvo Excavator 480DL 2013 model with breaker ...
# 89163  Volvo Excavator 480DL 2013 model with breaker ...
# 89164  Volvo Excavator 480DL 2013 model with breaker ...
# 89165                               Terex Backhoe Loader
# 89166                               Terex Backhoe Loader
# 89167                               Terex Backhoe Loader
# 89168                                            Backhoe
# 89169                                            Backhoe
# 89170                         heavy machinery equipments
# 89171                                       Wheel Loader
# 89172                                 Jcb Backhoe Loader
# 89173                                 Jcb Backhoe Loader
# 89174                                  Vibrating Rollers
# 89175                                  Vibrating Rollers
# 89176                                Excavator C.WT 4.2T
# 89177                                Excavator C.WT 4.2T
# 89178                                  Mining Excavators
# 89179                                  Mining Excavators
# 89180   Tracked Excavator Rubber Tracks / Zero Tailswing
# 89181                                         JCB Bushes
# 89182                                           Backhoes
# 89183                                       Earth Movers
# 89184                                    Poclain Machine
#
#                                               SMALL_DESC  \
# 0        450/10800 JCB Casting Assy Differential Housing
# 1      <p><b>Double Drum Mini Roller with Seat Drive<...
# 2      <p><b>Double Drum Mini Roller with Seat Drive<...
# 3                                      DOZER / bulldozer
# 4                                      DOZER / bulldozer
# 5      Backed by a team of highly skilled designers a...
# 6      Backed by a team of highly skilled designers a...
# 7      <p>Justifying our position in the national mar...
# 8      <p>Justifying our position in the national mar...
# 9      Being a quality-centric organization of this i...
# 10     Being a quality-centric organization of this i...
# 11              <p dir="ltr">9996403597 , 9896107960</p>
# 12              <p dir="ltr">9996403597 , 9896107960</p>
# 13              <p dir="ltr">9996403597 , 9896107960</p>
# 14              <p dir="ltr">9996403597 , 9896107960</p>
# 15     <p>One can avail from us a quality approved as...
# 16                                 L&T 9020 Wheel Loader
# 17                                 L&T 9020 Wheel Loader
# 18     L933 issuitable for bulk materials, with high ...
# 19     L933 issuitable for bulk materials, with high ...
# 20     L933 issuitable for bulk materials, with high ...
# 21                                      JCB Synchronizer
# 22                                Polished Excavator Pin
# 23                                Polished Excavator Pin
# 24                                Polished Excavator Pin
# 25                                        JCB Tooth Bolt
# 26                        Sany SY210C-9 21 Ton Excavator
# 27                        Sany SY210C-9 21 Ton Excavator
# 28     <p>We are an accomplished organization which h...
# 29     In line with clients' diverse requirements, we...
# ...                                                  ...
# 89155   We are unique supplier of JCB Skid Steer Loader.
# 89156   We are unique supplier of JCB Skid Steer Loader.
# 89157   We are unique supplier of JCB Skid Steer Loader.
# 89158                                  Toro Power Shovel
# 89159                Plant Hire Earth Movers Contractors
# 89160                              Landt Poclain Machine
# 89161  <p> <p>Get a Woods Groundbreaker&reg; Backhoe ...
# 89162  Volvo 480 excavator with breaker running condi...
# 89163  Volvo 480 excavator with breaker running condi...
# 89164  Volvo 480 excavator with breaker running condi...
# 89165                               Terex Backhoe Loader
# 89166                               Terex Backhoe Loader
# 89167                               Terex Backhoe Loader
# 89168                                            Backhoe
# 89169                                            Backhoe
# 89170                         heavy machinery equipments
# 89171  We have variouse brand of Wheel Loader of all ...
# 89172                                 Jcb Backhoe Loader
# 89173                                 Jcb Backhoe Loader
# 89174  <p>A full range of Rollers are available;</p> ...
# 89175  <p>A full range of Rollers are available;</p> ...
# 89176                                Excavator C.WT 4.2T
# 89177                                Excavator C.WT 4.2T
# 89178                                  Mining Excavators
# 89179                                  Mining Excavators
# 89180  <p>The JCB 8080 is a 8 tonne, zero tailswing m...
# 89181                                         JCB Bushes
# 89182                                           Backhoes
# 89183                                       Earth Movers
# 89184                                    Poclain Machine
#
#                     PRIME_MCAT_NAME  PRIME_MCAT_ID  FK_MCAT_TYPE_ID  PMCAT_ID  \
# 0                    JCB Spare Part         183008              NaN     65576
# 1                       Road Roller          20861              2.0     65024
# 2                  Vibrating Roller         136851              NaN     20861
# 3                         Bulldozer          77603              2.0       431
# 4                     Crawler Dozer          73183              NaN     77603
# 5                             Truck          78338              2.0     30252
# 6                     Mining Trucks          33137              0.0     78338
# 7                     Wheel Loaders          41181              2.0       431
# 8                 L&T Wheel Loaders         203649              0.0     41181
# 9                         Bulldozer          77603              2.0       431
# 10                   Used Bulldozer         142555              NaN     77603
# 11                         Trencher         203197              3.0       431
# 12            Trench Digger Machine         142366              0.0    203197
# 13                         Trencher         203197              3.0       431
# 14            Trench Digger Machine         142366              0.0    203197
# 15                   JCB Spare Part         183008              NaN     65576
# 16                    Wheel Loaders          41181              2.0       431
# 17                L&T Wheel Loaders         203649              0.0     41181
# 18                    Wheel Loaders          41181              2.0       431
# 19                   Backhoe Loader          22752              2.0       431
# 20                     Mini Loaders         114132              NaN     73184
# 21                   JCB Spare Part         183008              NaN     65576
# 22                    Excavator Pin         183990              NaN    106197
# 23                    Excavator Pin         183990              NaN    106197
# 24                  Excavator Parts         106197              2.0     65576
# 25                   JCB Spare Part         183008              NaN     65576
# 26                        Excavator         113951              2.0       431
# 27                   SANY Excavator         193235              0.0    113951
# 28                   JCB Spare Part         183008              NaN     65576
# 29                   Backhoe Loader          22752              2.0       431
# ...                             ...            ...              ...       ...
# 89155        JCB Skid Steer Loaders         193369              0.0     37924
# 89156            Skid Steer Loaders          37924              2.0       431
# 89157        JCB Skid Steer Loaders         193369              0.0     37924
# 89158                  Power Shovel          35526              NaN    113951
# 89159                  Earth Movers          27188              0.0       431
# 89160               Poclain Machine         185100              NaN    113951
# 89161                Backhoe Loader          22752              2.0       431
# 89162               Volvo Excavator         184967              NaN    113951
# 89163                     Excavator         113951              2.0       431
# 89164                     Excavator         113951              2.0       431
# 89165                Backhoe Loader          22752              2.0       431
# 89166  Terex Manitou Backhoe Loader         193244              0.0     22752
# 89167  Terex Manitou Backhoe Loader         193244              0.0     22752
# 89168               Mini Excavators          32778              0.0    113951
# 89169                     Excavator         113951              2.0       431
# 89170         Earthmoving Equipment           6781              0.0       431
# 89171                 Wheel Loaders          41181              2.0       431
# 89172                Backhoe Loader          22752              2.0       431
# 89173            JCB Backhoe Loader         181819              0.0     22752
# 89174                   Road Roller          20861              2.0     65024
# 89175              Vibrating Roller         136851              NaN     20861
# 89176                     Excavator         113951              2.0       431
# 89177           Hydraulic Excavator          15607              0.0    113951
# 89178                     Excavator         113951              2.0       431
# 89179               Mini Excavators          32778              0.0    113951
# 89180                     Excavator         113951              2.0       431
# 89181                JCB Spare Part         183008              NaN     65576
# 89182                Backhoe Loader          22752              2.0       431
# 89183                  Earth Movers          27188              0.0       431
# 89184               Poclain Machine         185100              NaN    113951
#
#                         PMCAT_NAME              ...               \
# 0      Earthmoving Machinery Parts              ...
# 1        Road Construction Machine              ...
# 2                      Road Roller              ...
# 3            Earthmoving Machinery              ...
# 4                        Bulldozer              ...
# 5                      Heavy Truck              ...
# 6                            Truck              ...
# 7            Earthmoving Machinery              ...
# 8                    Wheel Loaders              ...
# 9            Earthmoving Machinery              ...
# 10                       Bulldozer              ...
# 11           Earthmoving Machinery              ...
# 12                        Trencher              ...
# 13           Earthmoving Machinery              ...
# 14                        Trencher              ...
# 15     Earthmoving Machinery Parts              ...
# 16           Earthmoving Machinery              ...
# 17                   Wheel Loaders              ...
# 18           Earthmoving Machinery              ...
# 19           Earthmoving Machinery              ...
# 20                      End Loader              ...
# 21     Earthmoving Machinery Parts              ...
# 22                 Excavator Parts              ...
# 23                 Excavator Parts              ...
# 24     Earthmoving Machinery Parts              ...
# 25     Earthmoving Machinery Parts              ...
# 26           Earthmoving Machinery              ...
# 27                       Excavator              ...
# 28     Earthmoving Machinery Parts              ...
# 29           Earthmoving Machinery              ...
# ...                            ...              ...
# 89155           Skid Steer Loaders              ...
# 89156        Earthmoving Machinery              ...
# 89157           Skid Steer Loaders              ...
# 89158                    Excavator              ...
# 89159        Earthmoving Machinery              ...
# 89160                    Excavator              ...
# 89161        Earthmoving Machinery              ...
# 89162                    Excavator              ...
# 89163        Earthmoving Machinery              ...
# 89164        Earthmoving Machinery              ...
# 89165        Earthmoving Machinery              ...
# 89166               Backhoe Loader              ...
# 89167               Backhoe Loader              ...
# 89168                    Excavator              ...
# 89169        Earthmoving Machinery              ...
# 89170        Earthmoving Machinery              ...
# 89171        Earthmoving Machinery              ...
# 89172        Earthmoving Machinery              ...
# 89173               Backhoe Loader              ...
# 89174    Road Construction Machine              ...
# 89175                  Road Roller              ...
# 89176        Earthmoving Machinery              ...
# 89177                    Excavator              ...
# 89178        Earthmoving Machinery              ...
# 89179                    Excavator              ...
# 89180        Earthmoving Machinery              ...
# 89181  Earthmoving Machinery Parts              ...
# 89182        Earthmoving Machinery              ...
# 89183        Earthmoving Machinery              ...
# 89184                    Excavator              ...
#
#                                      MAP_SUBCAT_NAMELIST  \
# 0      Excavators, Bulldozers, JCB Machines, Road Rol...
# 1      Concrete Batching Plant, Building & Constructi...
# 2      Concrete Batching Plant, Building & Constructi...
# 3      Excavators, Bulldozers, JCB Machines, Road Rol...
# 4      Excavators, Bulldozers, JCB Machines, Road Rol...
# 5      Excavators, Bulldozers, JCB Machines, Road Rol...
# 6      Excavators, Bulldozers, JCB Machines, Road Rol...
# 7      Excavators, Bulldozers, JCB Machines, Road Rol...
# 8      Excavators, Bulldozers, JCB Machines, Road Rol...
# 9      Excavators, Bulldozers, JCB Machines, Road Rol...
# 10     Excavators, Bulldozers, JCB Machines, Road Rol...
# 11     Excavators, Bulldozers, JCB Machines, Road Rol...
# 12     Excavators, Bulldozers, JCB Machines, Road Rol...
# 13     Excavators, Bulldozers, JCB Machines, Road Rol...
# 14     Excavators, Bulldozers, JCB Machines, Road Rol...
# 15     Excavators, Bulldozers, JCB Machines, Road Rol...
# 16     Excavators, Bulldozers, JCB Machines, Road Rol...
# 17     Excavators, Bulldozers, JCB Machines, Road Rol...
# 18     Excavators, Bulldozers, JCB Machines, Road Rol...
# 19     Excavators, Bulldozers, JCB Machines, Road Rol...
# 20     Excavators, Bulldozers, JCB Machines, Road Rol...
# 21     Excavators, Bulldozers, JCB Machines, Road Rol...
# 22     Excavators, Bulldozers, JCB Machines, Road Rol...
# 23     Excavators, Bulldozers, JCB Machines, Road Rol...
# 24     Excavators, Bulldozers, JCB Machines, Road Rol...
# 25     Excavators, Bulldozers, JCB Machines, Road Rol...
# 26     Excavators, Bulldozers, JCB Machines, Road Rol...
# 27     Excavators, Bulldozers, JCB Machines, Road Rol...
# 28     Excavators, Bulldozers, JCB Machines, Road Rol...
# 29     Excavators, Bulldozers, JCB Machines, Road Rol...
# ...                                                  ...
# 89155  Concrete Batching Plant, Building & Constructi...
# 89156  Concrete Batching Plant, Building & Constructi...
# 89157  Concrete Batching Plant, Building & Constructi...
# 89158  Earth Moving & Heavy Earth Moving Machinery & ...
# 89159  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89160  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89161  Earth Moving & Heavy Earth Moving Machinery & ...
# 89162  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89163  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89164  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89165  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89166  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89167  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89168  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89169  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89170  Earth Moving & Heavy Earth Moving Machinery & ...
# 89171  Earth Moving & Heavy Earth Moving Machinery & ...
# 89172  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89173  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89174  Concrete Batching Plant, Building & Constructi...
# 89175  Concrete Batching Plant, Building & Constructi...
# 89176  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89177  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89178  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89179  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89180  Earth Moving & Heavy Earth Moving Machinery & ...
# 89181  Excavators, Bulldozers, JCB Machines, Road Rol...
# 89182  Earth Moving & Heavy Earth Moving Machinery & ...
# 89183  Earth Moving & Heavy Earth Moving Machinery & ...
# 89184  Excavators, Bulldozers, JCB Machines, Road Rol...
#
#                                              ISQ_DETAILS MAP_HT_GRP_IDLIST  \
# 0      Brand==KV Tech::Model==450/10800::Machine Type...                ,,
# 1      After Sales Service Available==Yes::Brand/Make...                ,,
# 2      After Sales Service Available==Yes::Brand/Make...                ,,
# 3      Warranty==6 Months::Model==All ::Condition==Ne...               NaN
# 4      Warranty==6 Months::Model==All ::Condition==Ne...               NaN
# 5      Body Capacity Struck== 55.06yd3::Torque Rise==...               NaN
# 6      Body Capacity Struck== 55.06yd3::Torque Rise==...               NaN
# 7      Bucket Capacity==1.5-3.5m3::Brands==L&amp;amp;...                ,,
# 8      Bucket Capacity==1.5-3.5m3::Brands==L&amp;amp;...                ,,
# 9      Engine Displacement==19.3 litre::Type==Crawler...                ,,
# 10     Engine Displacement==19.3 litre::Type==Crawler...                ,,
# 11     Max Engine Power(HP)==50 to 60 hp::Condition==...                ,,
# 12     Max Engine Power(HP)==50 to 60 hp::Condition==...                ,,
# 13     Max Engine Power(HP)==50 to 60 hp::Condition==...                ,,
# 14     Max Engine Power(HP)==50 to 60 hp::Condition==...                ,,
# 15     Pack Type==Carton Box::Color==Yellow::Brand==B...                ,,
# 16     Brand==L&amp;amp;T::Standard Operating Weight=...                ,,
# 17     Brand==L&amp;amp;T::Standard Operating Weight=...                ,,
# 18                    Rated Power==96 Kn ::Power==3000kg               NaN
# 19                    Rated Power==96 Kn ::Power==3000kg               NaN
# 20                    Rated Power==96 Kn ::Power==3000kg               NaN
# 21     Grade==Steel, 20 cr::Type==JCB Synchronizer::M...               NaN
# 22     Finish==Polished::Material==Mild Steel::Rust P...                ,,
# 23     Finish==Polished::Material==Mild Steel::Rust P...                ,,
# 24     Finish==Polished::Material==Mild Steel::Rust P...                ,,
# 25     Finish==Polished::Material==Cast Iron::Usage==...                ,,
# 26     Cab Height==2990mm::Model==SY210C-9 ::Rated En...                ,,
# 27     Cab Height==2990mm::Model==SY210C-9 ::Rated En...                ,,
# 28     Brand==US Spares::Packaging Type==Carton::Mate...                ,,
# 29     Material==Iron::Brand==Lamba Agroking::Type==B...                ,,
# ...                                                  ...               ...
# 89155                                                NaN                ,,
# 89156                                                NaN                ,,
# 89157                                                NaN                ,,
# 89158                                                NaN               NaN
# 89159                                                NaN               NaN
# 89160                                                NaN                ,,
# 89161                                                NaN               NaN
# 89162                                                NaN                ,,
# 89163                                                NaN                ,,
# 89164                                                NaN                ,,
# 89165                                                NaN                ,,
# 89166                                                NaN                ,,
# 89167                                                NaN                ,,
# 89168                                                NaN               NaN
# 89169                                                NaN               NaN
# 89170                                                NaN               NaN
# 89171                                                NaN               NaN
# 89172                                                NaN                ,,
# 89173                                                NaN                ,,
# 89174                                                NaN               NaN
# 89175                                                NaN               NaN
# 89176                                                NaN                ,,
# 89177                                                NaN                ,,
# 89178                                                NaN               NaN
# 89179                                                NaN               NaN
# 89180                                                NaN               NaN
# 89181                                                NaN                ,,
# 89182                                                NaN               NaN
# 89183                                                NaN               NaN
# 89184                                                NaN                ,,
#
#       MAP_HT_GRP_NAMELIST SDA_PC_ITEM_MIN_ORDER_QUANTITY  \
# 0                     NaN                             50
# 1                     NaN                            NaN
# 2                     NaN                            NaN
# 3                     NaN                            NaN
# 4                     NaN                            NaN
# 5                     NaN                            NaN
# 6                     NaN                            NaN
# 7                     NaN                            NaN
# 8                     NaN                            NaN
# 9                     NaN                            NaN
# 10                    NaN                            NaN
# 11                    NaN                              1
# 12                    NaN                              1
# 13                    NaN                              1
# 14                    NaN                              1
# 15                    NaN                            500
# 16                    NaN                            NaN
# 17                    NaN                            NaN
# 18                    NaN                            NaN
# 19                    NaN                            NaN
# 20                    NaN                            NaN
# 21                    NaN                            NaN
# 22                    NaN                            NaN
# 23                    NaN                            NaN
# 24                    NaN                            NaN
# 25                    NaN                            NaN
# 26                    NaN                            NaN
# 27                    NaN                            NaN
# 28                    NaN                             10
# 29                    NaN                            NaN
# ...                   ...                            ...
# 89155                 NaN                            NaN
# 89156                 NaN                            NaN
# 89157                 NaN                            NaN
# 89158                 NaN                            NaN
# 89159                 NaN                            NaN
# 89160                 NaN                            NaN
# 89161                 NaN                            NaN
# 89162                 NaN                              1
# 89163                 NaN                              1
# 89164                 NaN                              1
# 89165                 NaN                            NaN
# 89166                 NaN                            NaN
# 89167                 NaN                            NaN
# 89168                 NaN                            NaN
# 89169                 NaN                            NaN
# 89170                 NaN                            NaN
# 89171                 NaN                            NaN
# 89172                 NaN                            NaN
# 89173                 NaN                            NaN
# 89174                 NaN                            NaN
# 89175                 NaN                            NaN
# 89176                 NaN                            NaN
# 89177                 NaN                            NaN
# 89178                 NaN                            NaN
# 89179                 NaN                            NaN
# 89180                 NaN                            NaN
# 89181                 NaN                            NaN
# 89182                 NaN                            NaN
# 89183                 NaN                            NaN
# 89184                 NaN                            NaN
#
#       SDA_PC_ITEM_FOB_PRICE  \
# 0                      3100
# 1                    350000
# 2                    350000
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                   2727270
# 10                  2727270
# 11                   390000
# 12                   390000
# 13                   390000
# 14                   390000
# 15                       12
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                     2000
# 22                      300
# 23                      300
# 24                      300
# 25                       18
# 26                  5269970
# 27                  5269970
# 28                      300
# 29                      NaN
# ...                     ...
# 89155                   NaN
# 89156                   NaN
# 89157                   NaN
# 89158                   NaN
# 89159                   NaN
# 89160               2700000
# 89161                   NaN
# 89162               9000000
# 89163               9000000
# 89164               9000000
# 89165                   NaN
# 89166                   NaN
# 89167                   NaN
# 89168                   NaN
# 89169                   NaN
# 89170                   NaN
# 89171                   NaN
# 89172                   NaN
# 89173                   NaN
# 89174                   NaN
# 89175                   NaN
# 89176                   NaN
# 89177                   NaN
# 89178                   NaN
# 89179                   NaN
# 89180                   NaN
# 89181                   NaN
# 89182                   NaN
# 89183                   NaN
# 89184                   NaN
#
#                                                  PHOTO_1  \
# 0      http://5.imimg.com/data5/OI/IQ/MY-58521286/450...
# 1      http://5.imimg.com/data5/BA/HN/MY-2850251/hang...
# 2      http://5.imimg.com/data5/BA/HN/MY-2850251/hang...
# 3      http://4.imimg.com/data4/WC/YS/IMOB-29629451/r...
# 4      http://4.imimg.com/data4/WC/YS/IMOB-29629451/r...
# 5      http://3.imimg.com/data3/UI/UT/MY-3034425/off-...
# 6      http://3.imimg.com/data3/UI/UT/MY-3034425/off-...
# 7      http://5.imimg.com/data5/DY/MC/MY-65600416/l-t...
# 8      http://5.imimg.com/data5/DY/MC/MY-65600416/l-t...
# 9      http://4.imimg.com/data4/WC/IG/FUSIONW-4196482...
# 10     http://4.imimg.com/data4/WC/IG/FUSIONW-4196482...
# 11     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 12     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 13     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 14     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 15     http://4.imimg.com/data4/KW/KA/ANDROID-1883906...
# 16     http://5.imimg.com/data5/QR/LU/MY-15412012/l-1...
# 17     http://5.imimg.com/data5/QR/LU/MY-15412012/l-1...
# 18     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 19     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 20     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 21     http://5.imimg.com/data5/KQ/TA/MY-516034/jcb-s...
# 22     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 23     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 24     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 25     http://5.imimg.com/data5/IH/PM/MY-59514876/jcb...
# 26     http://5.imimg.com/data5/LK/VQ/MY-18042704/san...
# 27     http://5.imimg.com/data5/LK/VQ/MY-18042704/san...
# 28     http://5.imimg.com/data5/QL/XT/MY-16261014/jcb...
# 29     http://5.imimg.com/data5/BL/AY/MY-11787713/tra...
# ...                                                  ...
# 89155  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89156  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89157  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89158                                                NaN
# 89159                                                NaN
# 89160  http://4.imimg.com/data4/BS/LL/ANDROID-5889443...
# 89161  http://3.imimg.com/data3/JL/VK/HTVENDOR-148679...
# 89162  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89163  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89164  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89165                                                NaN
# 89166                                                NaN
# 89167                                                NaN
# 89168                                                NaN
# 89169                                                NaN
# 89170                                                NaN
# 89171  http://3.imimg.com/data3/CC/TB/MY-22978558/whe...
# 89172                                                NaN
# 89173                                                NaN
# 89174  http://3.imimg.com/data3/LD/VM/HTVENDOR-125548...
# 89175  http://3.imimg.com/data3/LD/VM/HTVENDOR-125548...
# 89176                                                NaN
# 89177                                                NaN
# 89178                                                NaN
# 89179                                                NaN
# 89180  http://3.imimg.com/data3/MF/OF/HELLOTD-1130416...
# 89181  http://4.imimg.com/data4/FN/ID/NSDMERP-5638456...
# 89182                                                NaN
# 89183                                                NaN
# 89184                                                NaN
#
#                                                  PHOTO_2  \
# 0      http://5.imimg.com/data5/OI/IQ/MY-58521286/450...
# 1      http://5.imimg.com/data5/BA/HN/MY-2850251/hang...
# 2      http://5.imimg.com/data5/BA/HN/MY-2850251/hang...
# 3      http://4.imimg.com/data4/WC/YS/IMOB-29629451/r...
# 4      http://4.imimg.com/data4/WC/YS/IMOB-29629451/r...
# 5      http://3.imimg.com/data3/UI/UT/MY-3034425/off-...
# 6      http://3.imimg.com/data3/UI/UT/MY-3034425/off-...
# 7      http://5.imimg.com/data5/DY/MC/MY-65600416/l-t...
# 8      http://5.imimg.com/data5/DY/MC/MY-65600416/l-t...
# 9      http://4.imimg.com/data4/WC/IG/FUSIONW-4196482...
# 10     http://4.imimg.com/data4/WC/IG/FUSIONW-4196482...
# 11     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 12     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 13     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 14     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 15     http://4.imimg.com/data4/KW/KA/ANDROID-1883906...
# 16     http://5.imimg.com/data5/QR/LU/MY-15412012/l-2...
# 17     http://5.imimg.com/data5/QR/LU/MY-15412012/l-2...
# 18     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 19     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 20     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 21     http://5.imimg.com/data5/KQ/TA/MY-516034/jcb-s...
# 22     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 23     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 24     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 25     http://5.imimg.com/data5/IH/PM/MY-59514876/jcb...
# 26     http://5.imimg.com/data5/LK/VQ/MY-18042704/san...
# 27     http://5.imimg.com/data5/LK/VQ/MY-18042704/san...
# 28     http://5.imimg.com/data5/QL/XT/MY-16261014/jcb...
# 29     http://5.imimg.com/data5/BL/AY/MY-11787713/tra...
# ...                                                  ...
# 89155  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89156  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89157  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89158     http://2.imimg.com/default-image/add-image.gif
# 89159     http://2.imimg.com/default-image/add-image.gif
# 89160  http://4.imimg.com/data4/BS/LL/ANDROID-5889443...
# 89161  http://3.imimg.com/data3/JL/VK/HTVENDOR-148679...
# 89162  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89163  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89164  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89165     http://2.imimg.com/default-image/add-image.gif
# 89166     http://2.imimg.com/default-image/add-image.gif
# 89167     http://2.imimg.com/default-image/add-image.gif
# 89168     http://2.imimg.com/default-image/add-image.gif
# 89169     http://2.imimg.com/default-image/add-image.gif
# 89170     http://2.imimg.com/default-image/add-image.gif
# 89171  http://3.imimg.com/data3/CC/TB/MY-22978558/whe...
# 89172     http://2.imimg.com/default-image/add-image.gif
# 89173     http://2.imimg.com/default-image/add-image.gif
# 89174  http://3.imimg.com/data3/LD/VM/HTVENDOR-125548...
# 89175  http://3.imimg.com/data3/LD/VM/HTVENDOR-125548...
# 89176     http://2.imimg.com/default-image/add-image.gif
# 89177     http://2.imimg.com/default-image/add-image.gif
# 89178     http://2.imimg.com/default-image/add-image.gif
# 89179     http://2.imimg.com/default-image/add-image.gif
# 89180  http://3.imimg.com/data3/MF/OF/HELLOTD-1130416...
# 89181  http://4.imimg.com/data4/FN/ID/NSDMERP-5638456...
# 89182     http://2.imimg.com/default-image/add-image.gif
# 89183     http://2.imimg.com/default-image/add-image.gif
# 89184     http://2.imimg.com/default-image/add-image.gif
#
#                                                  PHOTO_3  \
# 0      http://5.imimg.com/data5/OI/IQ/MY-58521286/450...
# 1      http://5.imimg.com/data5/BA/HN/MY-2850251/hang...
# 2      http://5.imimg.com/data5/BA/HN/MY-2850251/hang...
# 3      http://4.imimg.com/data4/WC/YS/IMOB-29629451/r...
# 4      http://4.imimg.com/data4/WC/YS/IMOB-29629451/r...
# 5      http://3.imimg.com/data3/UI/UT/MY-3034425/off-...
# 6      http://3.imimg.com/data3/UI/UT/MY-3034425/off-...
# 7      http://5.imimg.com/data5/DY/MC/MY-65600416/l-t...
# 8      http://5.imimg.com/data5/DY/MC/MY-65600416/l-t...
# 9      http://4.imimg.com/data4/WC/IG/FUSIONW-4196482...
# 10     http://4.imimg.com/data4/WC/IG/FUSIONW-4196482...
# 11     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 12     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 13     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 14     http://4.imimg.com/data4/QF/IA/ANDROID-2077238...
# 15     http://4.imimg.com/data4/KW/KA/ANDROID-1883906...
# 16     http://5.imimg.com/data5/QR/LU/MY-15412012/l-5...
# 17     http://5.imimg.com/data5/QR/LU/MY-15412012/l-5...
# 18     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 19     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 20     http://5.imimg.com/data5/AK/HD/MY-14630679/l93...
# 21     http://5.imimg.com/data5/KQ/TA/MY-516034/jcb-s...
# 22     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 23     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 24     http://5.imimg.com/data5/UV/QB/MY-69104252/pol...
# 25     http://5.imimg.com/data5/IH/PM/MY-59514876/jcb...
# 26     http://5.imimg.com/data5/LK/VQ/MY-18042704/san...
# 27     http://5.imimg.com/data5/LK/VQ/MY-18042704/san...
# 28     http://5.imimg.com/data5/QL/XT/MY-16261014/jcb...
# 29     http://5.imimg.com/data5/BL/AY/MY-11787713/tra...
# ...                                                  ...
# 89155  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89156  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89157  http://5.imimg.com/data5/RN/GD/MY-1770580/jcb-...
# 89158                                                NaN
# 89159                                                NaN
# 89160                                                NaN
# 89161  http://3.imimg.com/data3/JL/VK/HTVENDOR-148679...
# 89162  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89163  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89164  http://4.imimg.com/data4/DO/WL/ANDROID-1422959...
# 89165                                                NaN
# 89166                                                NaN
# 89167                                                NaN
# 89168                                                NaN
# 89169                                                NaN
# 89170                                                NaN
# 89171  http://3.imimg.com/data3/CC/TB/MY-22978558/whe...
# 89172                                                NaN
# 89173                                                NaN
# 89174                                                NaN
# 89175                                                NaN
# 89176                                                NaN
# 89177                                                NaN
# 89178                                                NaN
# 89179                                                NaN
# 89180  http://3.imimg.com/data3/MF/OF/HELLOTD-1130416...
# 89181  http://4.imimg.com/data4/FN/ID/NSDMERP-5638456...
# 89182                                                NaN
# 89183                                                NaN
# 89184                                                NaN
#
#                 SEARCH_TOPMOST_MCAT
# 0                    JCB Spare Part
# 1                       Road Roller
# 2                       Road Roller
# 3                     Crawler Dozer
# 4                     Crawler Dozer
# 5                     Mining Trucks
# 6                     Mining Trucks
# 7                     Wheel Loaders
# 8                     Wheel Loaders
# 9                    Used Bulldozer
# 10                   Used Bulldozer
# 11            Trench Digger Machine
# 12            Trench Digger Machine
# 13            Trench Digger Machine
# 14            Trench Digger Machine
# 15                        Wear Pads
# 16                    Wheel Loaders
# 17                    Wheel Loaders
# 18                    Wheel Loaders
# 19                    Wheel Loaders
# 20                    Wheel Loaders
# 21                   JCB Spare Part
# 22                    Excavator Pin
# 23                    Excavator Pin
# 24                    Excavator Pin
# 25                Bucket Tooth Bolt
# 26                   SANY Excavator
# 27                   SANY Excavator
# 28                   JCB Spare Part
# 29           Tractor Backhoe Loader
# ...                             ...
# 89155        JCB Skid Steer Loaders
# 89156        JCB Skid Steer Loaders
# 89157        JCB Skid Steer Loaders
# 89158                  Power Shovel
# 89159    Excavators Hiring Services
# 89160               Poclain Machine
# 89161                Backhoe Loader
# 89162               Volvo Excavator
# 89163               Volvo Excavator
# 89164               Volvo Excavator
# 89165  Terex Manitou Backhoe Loader
# 89166  Terex Manitou Backhoe Loader
# 89167  Terex Manitou Backhoe Loader
# 89168                Backhoe Loader
# 89169                Backhoe Loader
# 89170       Pharmaceutical Machines
# 89171                 Wheel Loaders
# 89172            JCB Backhoe Loader
# 89173            JCB Backhoe Loader
# 89174              Vibrating Roller
# 89175              Vibrating Roller
# 89176                     Excavator
# 89177                     Excavator
# 89178                     Excavator
# 89179                     Excavator
# 89180             Crawler Excavator
# 89181           Automotive Bushings
# 89182                Backhoe Loader
# 89183                  Earth Movers
# 89184               Poclain Machine
#
# [89185 rows x 26 columns]

# %%
len(df)
# Out:
# 89185

# %%
# df = df[df.MAP_SUBCAT_IDLIST == str(","+subcat_name+",")]

pmcat_training_data = getPmcatData(df)
len(pmcat_training_data)
# Out:
# 76258

# %%
display(pmcat_training_data)
# Out:
#                                           TITLE  \
# 1                 Mini Ride On Vibratory Roller
# 3                                 Crawler Dozer
# 5                     Off-Highway Mining Trucks
# 7                         L&T 9020 Wheel Loader
# 9                       Used Komatsu D355 Dozer
# 16                        L&T 9020 Wheel Loader
# 18                      L933 3-Ton Wheel Loader
# 19                      L933 3-Ton Wheel Loader
# 24                       Polished Excavator Pin
# 26               Sany SY210C-9 21 Ton Excavator
# 29                       Tractor Backhoe Loader
# 32                    JCB Excavator Tooth Point
# 35                      Hyundai Excavators Pins
# 40                                   Excavators
# 41           Walk Behind Vibratory Road Rollers
# 43                           5 ton Wheel Loader
# 44                    Industrial Backhoe Loader
# 46                            JCB Mining Bucket
# 48                 L T Komatsu Pc200 Excavators
# 52         Tata Hitachi Zaxis 220LC-M Excavator
# 56                             Excavator Bucket
# 58                       EC 5250 Road Compactor
# 61                          Hydraulic Excavator
# 65      Tata Hitachi EX 3600-6 Mining Excavator
# 68                        Sany Excavator SY 35U
# 69              JCB Robot 155 Skid Steer Loader
# 72                     Road Roller Hire Service
# 75                 Kobelco SK850LC HD Excavator
# 79                    Tata Hitachi Wheel Loader
# 80                    Tata Hitachi Wheel Loader
# ...                                         ...
# 82296                      Excavators Equipment
# 82342                         Portable Trencher
# 82363                     Trench Digger Machine
# 82366                     Trench Digger Machine
# 83573                    Motor Grader Equipment
# 84323                      Trencher Chain Types
# 84498                      Hydraulic Excavators
# 84567                     Bobcat LT112 Trencher
# 84634                           Trencher Supply
# 84802                     Trench Digger Machine
# 84975                        Rockwheel trencher
# 85106                     Trench Digger Machine
# 85107                     Trench Digger Machine
# 85179                         Ride on Trenchers
# 85490                            Heavy Trencher
# 85536                         Portable Trencher
# 85661                      Excavators Equipment
# 85664                      Excavators Equipment
# 85944             Tractor Trench Digger Machine
# 86054         Caterpillar India Private Limited
# 86080           JCB Chain Trench Digger Machine
# 86228                                  Trencher
# 86330                     Tractor Trench Digger
# 86599                             Mini Trencher
# 86942    Quad Hydrostatic Quad Trencher Machine
# 87827                           Chain Trenchers
# 87920                           Forest Trencher
# 88711  Horsepower Hydrostatic Trenchers Machine
# 88809                                  TRENCHER
# 89041                         Portable Trencher
#
#                                               SMALL_DESC  \
# 1      <p><b>Double Drum Mini Roller with Seat Drive<...
# 3                                      DOZER / bulldozer
# 5      Backed by a team of highly skilled designers a...
# 7      <p>Justifying our position in the national mar...
# 9      Being a quality-centric organization of this i...
# 16                                 L&T 9020 Wheel Loader
# 18     L933 issuitable for bulk materials, with high ...
# 19     L933 issuitable for bulk materials, with high ...
# 24                                Polished Excavator Pin
# 26                        Sany SY210C-9 21 Ton Excavator
# 29     In line with clients' diverse requirements, we...
# 32                             JCB Excavator Tooth Point
# 35                               Hyundai Excavators Pins
# 40     VOLVO EC210, 290, 360, 460, 480, 700, DAEWOO H...
# 41     Our double drum walk behind vibratory road rol...
# 43     <p><b>Optimum Efficiency</b></p><p><b>Cummins ...
# 44                             Industrial Backhoe Loader
# 46     We are leading supplier of <b>JCB Mining Bucke...
# 48                          L T Komatsu Pc200 Excavators
# 52     Product Discription :<br /><br />We are dealin...
# 56     We are a reputed entity in the industry, activ...
# 58     <p>With the help of professionals, our firm is...
# 61     The range of Hydraulic Excavators, available i...
# 65     <ul><li>The EX 3600-6 hydraulic excavator is k...
# 68     Higher efficiency, lower fuel consumption and ...
# 69     <p>The JCB ROBOT 155 Skid \r\nSteer Loader is ...
# 72     Escorts 5250 VIBRO ROLLER for Runway, Highway,...
# 75     We are offering a <b>Kobelco SK850LC HD Excava...
# 79     <p>Being a well-known firm, we are involved in...
# 80     <p>Being a well-known firm, we are involved in...
# ...                                                  ...
# 82296  <table border="0" width="95%" align="center"> ...
# 82342  <p>With the trencher attachment you can easily...
# 82363  <p>The&nbsp;&nbsp;Tractor Trencher&nbsp;system...
# 82366  <p>The&nbsp;&nbsp;Tractor Trencher&nbsp;system...
# 83573  <p>96 Komatsu 850 turbo charged, 12' blade 2' ...
# 84323  <p>We have a picture of the various types of T...
# 84498                               Hydraulic Excavators
# 84567                              Bobcat LT112 Trencher
# 84634                                    Trencher Supply
# 84802  We are a top notch supplier of&nbsp;Trench Dig...
# 84975  <p>HP74-D rockwheel is the ideal solution for ...
# 85106                              Trench Digger Machine
# 85107                              Trench Digger Machine
# 85179  <p>Designed to deal with spoil efficiently, ri...
# 85490                                     Heavy Trencher
# 85536                                  Portable Trencher
# 85661  <p><b> </b>10' Arm, 28" TG Pads, AC, Heat, Cab...
# 85664  <p><b> </b>10' Arm, 28" TG Pads, AC, Heat, Cab...
# 85944  We are a top-notch organization, engaged in pr...
# 86054  Caterpillar has been the world's leading manuf...
# 86080                    JCB Chain Trench Digger Machine
# 86228  <p>The compact trencher was introduced to the ...
# 86330  <p>The Tractor Trench Digger is used while gro...
# 86599                                      Mini Trencher
# 86942  <p>One look at the foundation of the RT115 Qua...
# 87827  We have made ourselves as a reliable and well-...
# 87920  <p>These categories&rsquo; heavy duty forest t...
# 88711  <p>The RT115 heavy-duty ride-on trencher sport...
# 88809  <p>BATTERY <br /> Amps 340 CCA <br /> HYDRAULI...
# 89041                                  Portable Trencher
#
#                     PRIME_MCAT_NAME  FK_MCAT_TYPE_ID  PRIME_SUBCAT_ID  \
# 1                       Road Roller              2.0            155.0
# 3                         Bulldozer              2.0            155.0
# 5                             Truck              2.0            246.0
# 7                     Wheel Loaders              2.0            155.0
# 9                         Bulldozer              2.0            155.0
# 16                    Wheel Loaders              2.0            155.0
# 18                    Wheel Loaders              2.0            155.0
# 19                   Backhoe Loader              2.0            155.0
# 24                  Excavator Parts              2.0            155.0
# 26                        Excavator              2.0            155.0
# 29                   Backhoe Loader              2.0            155.0
# 32                  Excavator Parts              2.0            155.0
# 35                  Excavator Parts              2.0            155.0
# 40                        Excavator              2.0            155.0
# 41                      Road Roller              2.0            155.0
# 43                    Wheel Loaders              2.0            155.0
# 44                   Backhoe Loader              2.0            155.0
# 46               Earthmoving Bucket              2.0            155.0
# 48                        Excavator              2.0            155.0
# 52                        Excavator              2.0            155.0
# 56               Earthmoving Bucket              2.0            155.0
# 58                      Road Roller              2.0            155.0
# 61                        Excavator              2.0            155.0
# 65                        Excavator              2.0            155.0
# 68                        Excavator              2.0            155.0
# 69               Skid Steer Loaders              2.0            155.0
# 72     Earthmoving Equipment Rental              2.0            632.0
# 75                        Excavator              2.0            155.0
# 79                    Wheel Loaders              2.0            155.0
# 80                    Wheel Loaders              2.0            155.0
# ...                             ...              ...              ...
# 82296                      Trencher              3.0            155.0
# 82342                      Trencher              3.0            155.0
# 82363                      Trencher              3.0            155.0
# 82366                      Trencher              3.0            155.0
# 83573                      Trencher              3.0            155.0
# 84323                      Trencher              3.0            155.0
# 84498                      Trencher              3.0            155.0
# 84567                      Trencher              3.0            155.0
# 84634                      Trencher              3.0            155.0
# 84802                      Trencher              3.0            155.0
# 84975                      Trencher              3.0            155.0
# 85106                      Trencher              3.0            155.0
# 85107                      Trencher              3.0            155.0
# 85179                      Trencher              3.0            155.0
# 85490                      Trencher              3.0            155.0
# 85536                      Trencher              3.0            155.0
# 85661                      Trencher              3.0            155.0
# 85664                      Trencher              3.0            155.0
# 85944                      Trencher              3.0            155.0
# 86054                    Thermistor              3.0             68.0
# 86080                      Trencher              3.0            155.0
# 86228                      Trencher              3.0            155.0
# 86330                      Trencher              3.0            155.0
# 86599                      Trencher              3.0            155.0
# 86942                      Trencher              3.0            155.0
# 87827                      Trencher              3.0            155.0
# 87920                      Trencher              3.0            155.0
# 88711                      Trencher              3.0            155.0
# 88809                      Trencher              3.0            155.0
# 89041                      Trencher              3.0            155.0
#
#                                       ISQ_DETAILS4_INDEX  \
# 1             Yes Bellstone Fyl Ride On 2.5 ton 6 Months
# 3      6 Months All  New Coal Bulldozing Type 10 Tons...
# 5       55.06yd3 23.0%  37.5mph  7.5in 3476.0lb ft 10...
# 7      1.5-3.5m3 L&amp;T 131.5 HP @ 2300 rpm Ashok Le...
# 9      19.3 litre Crawler Dozer D355 Used 20- 30 Tons...
# 16     L&amp;T 11.5 T 1.5 m3 -GP 3,500 kg Fixed Front...
# 18                                         96 Kn  3000kg
# 19                                         96 Kn  3000kg
# 24                     Polished Mild Steel Yes Box Round
# 26     2990mm SY210C-9  104/2000 kW/rpm 571N.m@1300rp...
# 29          Iron Lamba Agroking Back Loader Wheel Loader
# 32                                 JCB  Excavator  Metal
# 35                    Standard As per required Customize
# 40                                                Yellow
# 41     Diesel Double Drum Roller Cosmos Cement Concre...
# 43                                              SYL956H5
# 44     66 Degree 76 HP 1 Cubic Meter, 0.24 Cubic Mete...
# 46                      Iron Excavator Bucket New Orange
# 48     2 x 12V Komatsu 2008 to 2011 Used Machine 1.0 cum
# 52                                                   New
# 56                                      Orange Metal New
# 58     High : 1.72 mm, Low: 0.8 mm Single Drum Roller...
# 61                                              4-80 Ton
# 65     Tata Hitachi Heaped : 21.0 m3   23.0 m3 3,59,0...
# 68          SY35U-Tier 3 SY 35U Excavator Brand new SANY
# 69                                   12 Months Robot 155
# 72     10T class. Vibratory. Diesel Yellow Diesel Rol...
# 75                         Kobelco 8.4 {8.4}  2.8-5.4 m3
# 79     1.5 - 3.0 m3 Tata Hitachi New 12 Months Yes 12...
# 80     1.5 - 3.0 m3 Tata Hitachi New 12 Months Yes 12...
# ...                                                  ...
# 82296                                                NaN
# 82342                                                NaN
# 82363                                                NaN
# 82366                                                NaN
# 83573                                                NaN
# 84323                                                NaN
# 84498                                                NaN
# 84567                                                NaN
# 84634                                                NaN
# 84802                                                NaN
# 84975                                                NaN
# 85106                                                NaN
# 85107                                                NaN
# 85179                                                NaN
# 85490                                                NaN
# 85536                                                NaN
# 85661                                                NaN
# 85664                                                NaN
# 85944                                                NaN
# 86054                                                NaN
# 86080                                                NaN
# 86228                                                NaN
# 86330                                                NaN
# 86599                                                NaN
# 86942                                                NaN
# 87827                                                NaN
# 87920                                                NaN
# 88711                                                NaN
# 88809                                                NaN
# 89041                                                NaN
#
#                                        MAP_MCAT_NAMELIST  \
# 1                           Vibrating Roller,Road Roller
# 3                                Crawler Dozer,Bulldozer
# 5                                    Truck,Mining Trucks
# 7                        L&T Wheel Loaders,Wheel Loaders
# 9                               Used Bulldozer,Bulldozer
# 16                       L&T Wheel Loaders,Wheel Loaders
# 18             Wheel Loaders,Backhoe Loader,Mini Loaders
# 19             Wheel Loaders,Backhoe Loader,Mini Loaders
# 24                                         Excavator Pin
# 26                              SANY Excavator,Excavator
# 29                 Tractor Backhoe Loader,Backhoe Loader
# 32                 Excavator Tooth Point,Excavator Parts
# 35                         Excavator Pin,Excavator Parts
# 40                                             Excavator
# 41                          Vibrating Roller,Road Roller
# 43                                         Wheel Loaders
# 44                                        Backhoe Loader
# 46                   Excavator Bucket,Earthmoving Bucket
# 48                           Komatsu Excavator,Excavator
# 52            Hitachi Excavator,Excavator,TATA Excavator
# 56     Excavator Bucket,Heavy Duty Bucket,Earthmoving...
# 58                                           Road Roller
# 61       Hydraulic Excavator,Crawler Excavator,Excavator
# 65                           Hitachi Excavator,Excavator
# 68              SANY Excavator,Mini Excavators,Excavator
# 69             JCB Skid Steer Loaders,Skid Steer Loaders
# 72     Roller Rental Service,Construction Equipment R...
# 75                           Kobelco Excavator,Excavator
# 79              TATA Hitachi Wheel Loaders,Wheel Loaders
# 80              TATA Hitachi Wheel Loaders,Wheel Loaders
# ...                                                  ...
# 82296                         Portable Trencher,Trencher
# 82342                         Portable Trencher,Trencher
# 82363                     Trench Digger Machine,Trencher
# 82366                     Trench Digger Machine,Trencher
# 83573                         Portable Trencher,Trencher
# 84323                         Portable Trencher,Trencher
# 84498                         Portable Trencher,Trencher
# 84567                     Trench Digger Machine,Trencher
# 84634                                           Trencher
# 84802                     Trench Digger Machine,Trencher
# 84975                     Trench Digger Machine,Trencher
# 85106                     Trench Digger Machine,Trencher
# 85107                     Trench Digger Machine,Trencher
# 85179                         Portable Trencher,Trencher
# 85490                       Trencher,Tractor Attachments
# 85536                         Portable Trencher,Trencher
# 85661                         Portable Trencher,Trencher
# 85664                         Portable Trencher,Trencher
# 85944                     Trench Digger Machine,Trencher
# 86054                                                NaN
# 86080                     Trench Digger Machine,Trencher
# 86228                         Portable Trencher,Trencher
# 86330                     Trench Digger Machine,Trencher
# 86599                         Portable Trencher,Trencher
# 86942                         Portable Trencher,Trencher
# 87827                     Trencher,Earthmoving Machinery
# 87920                         Portable Trencher,Trencher
# 88711                         Portable Trencher,Trencher
# 88809                         Portable Trencher,Trencher
# 89041                         Portable Trencher,Trencher
#
#               SEARCH_TOPMOST_MCAT
# 1                     Road Roller
# 3                   Crawler Dozer
# 5                   Mining Trucks
# 7                   Wheel Loaders
# 9                  Used Bulldozer
# 16                  Wheel Loaders
# 18                  Wheel Loaders
# 19                  Wheel Loaders
# 24                  Excavator Pin
# 26                 SANY Excavator
# 29         Tractor Backhoe Loader
# 32          Excavator Tooth Point
# 35                  Excavator Pin
# 40                      Excavator
# 41             Walk Behind Roller
# 43                  Wheel Loaders
# 44                 Backhoe Loader
# 46               Excavator Bucket
# 48                  L&T Excavator
# 52              Hitachi Excavator
# 56               Excavator Bucket
# 58                    Road Roller
# 61            Hydraulic Excavator
# 65              Hitachi Excavator
# 68                 SANY Excavator
# 69         JCB Skid Steer Loaders
# 72                  Roller Rental
# 75              Kobelco Excavator
# 79     TATA Hitachi Wheel Loaders
# 80     TATA Hitachi Wheel Loaders
# ...                           ...
# 82296        Excavation Equipment
# 82342           Portable Trencher
# 82363       Trench Digger Machine
# 82366       Trench Digger Machine
# 83573                Motor Grader
# 84323                    Trencher
# 84498         Hydraulic Excavator
# 84567                    Trencher
# 84634                    Trencher
# 84802       Trench Digger Machine
# 84975                         NaN
# 85106       Trench Digger Machine
# 85107       Trench Digger Machine
# 85179                 Ride On Toy
# 85490                    Trencher
# 85536           Portable Trencher
# 85661        Excavation Equipment
# 85664        Excavation Equipment
# 85944       Trench Digger Machine
# 86054                         NaN
# 86080       Trench Digger Machine
# 86228                    Trencher
# 86330       Trench Digger Machine
# 86599           Portable Trencher
# 86942                  Quadcopter
# 87827                    Trencher
# 87920                    Trencher
# 88711                         NaN
# 88809                    Trencher
# 89041           Portable Trencher
#
# [76258 rows x 8 columns]

# %%
# pmcat_training_data.drop(pmcat_training_data.index[[483]])

pmcat_training_data = refine_pmcat_data(pmcat_training_data)
len(pmcat_training_data)
# Out:
# 65117

# %%
list(pmcat_training_data.PRIME_MCAT_NAME.unique())
# Out:
# ['Bulldozer',
#  'Wheel Loaders',
#  'Backhoe Loader',
#  'Excavator Parts',
#  'Excavator',
#  'Earthmoving Bucket',
#  'Skid Steer Loaders',
#  'Motor Grader',
#  'End Loader',
#  'Road Roller',
#  'Trencher']

# %%
pmcat_training_data = remove_newline_character(pmcat_training_data)

# %%
base_directory = "./FastText_Waterfall_Model/subcat_"+str(subcat_name)+"/pmcat/input_"+str(subcat_name)+"/"
write_dataframe_to_csv(base_directory, str("pmcat_data_"+ subcat_name +".csv"), pmcat_training_data)
# pmcat_training_data.to_csv(base_directory + "pmcat_data_"+ subcat_name +".csv", index=False,header=False, sep='\t', encoding='utf-8')

# %%
base_directory = "./FastText_Waterfall_Model/subcat_"+str(subcat_name)+"/pmcat/output_"+str(subcat_name)+"/"
df_cleaned = clean_and_preProcess_data(pmcat_training_data)
df_cleaned_updated = df_cleaned.FASTTEXT_CORPUS.dropna()
df_cleaned_updated.to_csv(base_directory+str("pmcat_data_"+ subcat_name +".txt"), index=None, header=False)

# %%
df_child_data = get_child_data(df)

# %%
df_child_data.head()
print(len(df_child_data))
# Out:
# 49332

# %%
df_child_groups = refined_child_groups(df_child_data)

# %%
print(df_child_groups.PMCAT_NAME.count())
# Out:
# PMCAT_NAME
# Backhoe Loader         2903
# Bulldozer              2050
# Earthmoving Bucket     2480
# End Loader             1118
# Excavator             12270
# Excavator Parts        2650
# Motor Grader            682
# Road Roller            2088
# Skid Steer Loaders      420
# Trencher                316
# Wheel Loaders          1990
# Name: PMCAT_NAME, dtype: int64

# %%
base_directory = "./FastText_Waterfall_Model/subcat_"+str(subcat_name)+"/child/input_"+str(subcat_name)+"/"
out_directory = "./FastText_Waterfall_Model/subcat_"+str(subcat_name)+"/child/output_"+str(subcat_name)+"/"
for name, group in df_child_groups:
    group = remove_newline_character(group)
    group_fields = group[['TITLE','SMALL_DESC','PRIME_MCAT_NAME','FK_MCAT_TYPE_ID','PRIME_SUBCAT_ID','ISQ_DETAILS4_INDEX','MAP_MCAT_NAMELIST','SEARCH_TOPMOST_MCAT']].copy()
    
    write_dataframe_to_csv(base_directory, str(str(name.replace(" ","_"))+".csv"), group_fields)
    
    df_cleaned = clean_and_preProcess_data(group_fields)
    df_cleaned_updated = df_cleaned.FASTTEXT_CORPUS.dropna()
    df_cleaned_updated.to_csv(out_directory+str(str(name.replace(" ","_"))+".txt"), index=None, header=False)

#     group_fields.to_csv("./FastText_Waterfall_Model/subcat_155/child/input_155/"+str(name.replace(" ","_"))+".csv", index=False, sep='\t', encoding='utf-8')

# %%
combined_parsed_file_name="combined.txt"
combined_shuffled_file_name="combined_shuffled.txt"
train_file_name="singleLabel_train_"+subcat_name
test_file_name="single_label_test_"+subcat_name
model_name="supervised_classifier_model_CATID_"+subcat_name
split=.9

# %%
def generate_files_and_trainModel(modelType, modelName):
    
    base_directory = "./FastText_Waterfall_Model/subcat_"+subcat_name+"/"
    input_path= base_directory+modelType+"/"+"input_"+subcat_name+"/"
    output_path= base_directory+modelType+"/"+"output_"+subcat_name+"/"
    KFold_Validation_Files_path= base_directory+modelType+"/"+"kFold_validation_"+subcat_name+"/"
    model_path=base_directory+modelType+"/"+"model_"+subcat_name+"/"
    
#     file = input_path+modelName+".csv"
#     print("Parsing File:"+file)
#     parsed_items=preProcess(file)
#     write_to_file(parsed_items,output_path,str(str(modelName)+".txt"),True)
#     print("Total Lines Parsed ="+str(len(parsed_items))) 
#     print("File Parsing Completed")
    
    print("Shuffling File..")
    total_data=randomly_shuffle_file(output_path+str(str(modelName)+".txt"),output_path+modelName+"_shuffled.txt")
    print("Total Data Len"+str(len(total_data)))
    
    if modelType == "child":
        split = 1.0
    else:
        split = 0.9
        
    print("Splitting Files..")
    train_data=total_data[0:int(len(total_data)*split)]
    print("Train Data Len"+str(len(train_data)))
    test_data =total_data[int(len(total_data)*split):len(total_data)-1]
    print("Test Data Len"+str(len(test_data)))
    
    if modelType == "child":
        
        print("Saving Files...")
        write_to_file(train_data,output_path,modelName,False)
#         write_to_file(test_data,output_path,test_file_name,False)
    
    print(total_data[0:10])
    
    if modelType == "pmcat":
        from sklearn.model_selection import KFold # import KFold
        import numpy as np
        
        kf = KFold(n_splits=10) # Define the split - into 2 folds 
        kf.get_n_splits(total_data) # returns the number of splitting iterations in the cross-validator
        print(kf) 
        KFold(n_splits=10, random_state=None, shuffle=False)
        file_number = 1
        precision=0
        recall=0
        for train_index, test_index in kf.split(total_data):
            train_data = np.array(total_data)[train_index]
            test_data = np.array(total_data)[test_index]
            write_to_file(train_data,KFold_Validation_Files_path,train_file_name+"_"+str(file_number)+".txt",False)
            write_to_file(test_data,KFold_Validation_Files_path,test_file_name+"_"+str(file_number)+".txt",False)
            
            print("Iteration:- " + str(file_number))
            file_number=file_number+1
        
        i=1
        final_precision=0
        final_recall=0
        while i < 11:
            classifier = fasttext.supervised(KFold_Validation_Files_path+train_file_name+"_"+str(i)+".txt",
                                             model_path+model_name+"_"+str(i), label_prefix='__label__',
                                             epoch=50,lr=1.0,word_ngrams=1,bucket=200000,dim=50,loss='hs')
    #     ,lr_update_rate=100,thread=4,minn=4
        
            classifier_test_result=classifier.test(KFold_Validation_Files_path+test_file_name+"_"+str(i)+".txt")
            precision=classifier_test_result.precision
            recall=classifier_test_result.recall
            final_precision=final_precision+precision
            final_recall=final_recall+recall
            print("Precision "+ str(i)+ " is:   " + str(precision))
            print("Recall "+ str(i)+ " is:   " + str(recall))
        #     print("Iteration:- " + str(i))
            i=i+1
    
        print("Average Precision is:-" + str(final_precision/10))
        print("Average Recall is:-" + str(final_recall/10))
        
        pmcat_classifier = fasttext.supervised(output_path+modelName+"_shuffled.txt",
                                             model_path+model_name+"_pmcat_data", label_prefix='__label__',
                                             epoch=50,lr=1.0,word_ngrams=1,bucket=200000,dim=50,loss='hs')
    
        def getTestSetForValidation(file_name,no_of_cases):
            texts=[]
            num_tests=int(no_of_cases)
            with open(file_name) as infile:
                num_line=0
                for line in infile:
                    num_line=num_line+1
                    texts.append(line)
                    if num_line >num_tests:
                        break
            return texts
        
        texts = getTestSetForValidation(KFold_Validation_Files_path+test_file_name+"_1.txt",1000)
        
        classifier = fasttext.load_model(model_path+model_name+"_1.bin")
        
        predicted_labels = classifier.predict_proba(texts,k=1)
        i=0
        for labels in predicted_labels:
            count=0
            lab=""
            while count < len(labels):
                if lab=="":
                    lab = str(labels[count]).replace("('","").replace("'","").replace(")","")
                else:
                    lab = str(lab)+"="+str(labels[count]).replace("('","").replace("'","").replace(")","")
                count +=1
                lab = str(lab).replace("__label__","")
            finalString = str(lab).split(",")[0].replace("_"," ")+"\t"+str(lab).split(",")[1]+"\t"+str(texts[i]).split(" ")[0].replace("__label__","").replace("_"," ")+"\t"+ " ".join(str(texts[i]).split(" ")[1:])
#             finalString =  str(" ".join(str(texts[i]).split(" ")[1:]))+"\t"+str(texts[i]).split(" ")[0].replace("__label__","").replace("_"," ")+"\t"+str(lab).split(",")[0].replace("_"," ")+"\t"+str(lab).split(",")[1]
            print(finalString)
        #     ML_Single_label.write(str(lab)+"?"+str(texts[i]))
            i=i+1
    else:
        classifier = fasttext.supervised(output_path+modelName,
                                             model_path+model_name+"_"+modelName, label_prefix='__label__',
                                             epoch=50,lr=1.0,word_ngrams=1,bucket=200000,dim=50,loss='hs')
        print("Model Successfully Loaded for model name:- " + modelName)

# %%
subcat_name = "155"

# %%
generate_files_and_trainModel("pmcat","pmcat_data_"+str(subcat_name)+"")
# Out:
# Shuffling File..
# Total Data Len64028
# Splitting Files..
# Train Data Len57625
# Test Data Len6402
# ['__label__Excavator wheel excavator wheeled excavator\n', '__label__Backhoe_Loader super loader backhoe loader\n', '__label__Excavator_Parts large hydraulic excavatorr 9250 excavator\n', '__label__Skid_Steer_Loaders steer bobcat bobcat skid steer loader\n', '__label__Motor_Grader orbiter zero tail swing drive engine ability upgrade attachments front rear gas diesel models orbital welding service\n', '__label__Wheel_Loaders construction jcb wheel loaders jcb wheel loaders\n', '__label__Bulldozer caterpillar track dozers crawler dozer\n', '__label__Excavator mini excavators mini excavators\n', '__label__Excavator_Parts bucket tooth point excavator parts\n', '__label__Wheel_Loaders wheel loaders wheel loaders\n']
# KFold(n_splits=10, random_state=None, shuffle=False)
# Iteration:- 1
# Iteration:- 2
# Iteration:- 3
# Iteration:- 4
# Iteration:- 5
# Iteration:- 6
# Iteration:- 7
# Iteration:- 8
# Iteration:- 9
# Iteration:- 10
# Precision 1 is:   0.8246134624394815
# Recall 1 is:   0.8246134624394815
# Precision 2 is:   0.8535061689832891
# Recall 2 is:   0.8535061689832891
# Precision 3 is:   0.7846322036545369
# Recall 3 is:   0.7846322036545369
# Precision 4 is:   0.8478838044666562
# Recall 4 is:   0.8478838044666562
# Precision 5 is:   0.8478838044666562
# Recall 5 is:   0.8478838044666562
# Precision 6 is:   0.8402311416523505
# Recall 6 is:   0.8402311416523505
# Precision 7 is:   0.730282679993753
# Recall 7 is:   0.730282679993753
# Precision 8 is:   0.8489770420115571
# Recall 8 is:   0.8489770420115571

# %%
type(df_child_groups.groups.keys())
for key in df_child_groups.groups.keys():
    print(key)

# %%
def get_file_names_to_parse(input_path):
    files_to_parse = [str(f).replace(".txt","") for f in listdir(input_path) if isfile(join(input_path, f))]
    print("Total Child Models to load="+str(len(files_to_parse)))
    return files_to_parse

# %%
childModelsName = get_file_names_to_parse(str(child_directory)
childModelsName

# %%
i = 0
while i < len(childModelsName):
    generate_files_and_trainModel("child",str(childModelsName[i]))
    i+=1

# %%
# for key in df_child_groups.groups.keys():
#     generate_files_and_trainModel("child",key.replace(" ","_"))

# %%
# !pip install xrange
# Out:
# Collecting xrange
#   Could not find a version that satisfies the requirement xrange (from versions: )
# No matching distribution found for xrange
# You are using pip version 18.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# df.TITLE.to_csv("./subcat_title_updated_products.csv", index=False, header=None)

# %%
import itertools
import xrange

L = ['a','b','c']
c = []

for i in xrange(1, len(L)+1):
    l = [list(x) for x in itertools.combinations(L, i)]
    c.extend(l)
d=[]
l = [list(x) for x in itertools.combinations(L, 2)]
d.extend(l)
x= (int(len(c)) + int(len(d)))
# Out:
# ------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-4-c04ff8ef504d> in <module>()
#       1 import itertools
# ----> 2 import xrange
#       3
#       4 L = ['a','b','c']
#       5 c = []
#
# ModuleNotFoundError: No module named 'xrange'
